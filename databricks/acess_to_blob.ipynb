# %%
senha = dbutils.secrets.get(scope = 'scope-name', key = 'db-key')

dbutils.fs.mount(source = "wasbs://container@storage_account.blob.core.windows.net",
                 mount_point = "/mnt/mount_path",
                 extra_configs = {"fs.azure.account.key.storage_account.blob.core.windows.net":senha})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[1]: True</div>
